# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv("boston.csv")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
X = df.drop("PRICE",axis= 1)
y= df["PRICE"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
 test_size=0.33, random_state=9)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_regr = LinearRegression()
lin_regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lin_test_pred= lin_regr.predict(X_test)

# %%
lin_test_pred
# Out:
# array([20.56826991, 14.90884713, 34.16691649, 14.32892394, 19.29784374,
#        23.31650765, 34.76830157, 27.94146393, 20.44823948, 16.05535812,
#        17.91446724, 27.5254312 , 16.5517998 , 32.53302895, 14.0705019 ,
#        30.67438129, 18.78403706, 22.57812295, 31.08732215, 17.4390819 ,
#        24.88499876,  5.27258377, 23.9774669 , 19.98545204, 27.82428717,
#        43.62363776, 27.14490774, 15.73301318, 19.54796184, 24.02986597,
#        13.34256412, 13.44624053, 21.1287616 , 16.10270234, 20.97221726,
#        14.74524521, 30.91257744, 17.93244358, 13.03501704, 40.28754598,
#        16.8230958 , 22.85950822, 13.65338337, 38.53034648, 34.31911   ,
#        21.05234416, 28.28258437, 24.73168616,  5.86808312, 26.95993759,
#        31.68879317, 34.76914551, 17.10542919, 26.93704839,  8.63159076,
#        18.51501364, 19.41320117, 10.22842941, 31.51174315, 16.9126258 ,
#        19.30074408, 28.23957656, 14.46059674,  1.63362903, 32.89038995,
#        18.23302047, 17.46439005, 19.37452263, 17.27417424, 22.30010037,
#        40.20828215,  5.68469155, 34.3568353 , 22.32530166, 18.47734562,
#        25.93950084, 21.85083817, 39.64178509, 18.22597222, 19.24685497,
#        20.36234993, 30.41583189, 22.03912711, 37.60174219, 13.59715061,
#        25.93096713, 26.64937027, 19.06578191, 13.70833035, 16.34797799,
#        23.39565841, 17.92466533, 28.40650311, 22.45345895, 18.15457683,
#        30.9574862 , 24.66801951, 13.69587953, 20.66954527, 25.90835065,
#        30.50092439, 25.98165954, 27.13859342, 21.04954009, 31.899731  ,
#        32.40406944, 16.51071566, 30.21979336, 25.14728782, 31.21913115,
#        23.77818054, 16.26663499, 19.68576028, 32.67884133, 23.47362221,
#        34.98061669, 22.01567826, 21.79420065, 20.66962792, 20.76312465,
#        18.72212765, 24.18455197, 16.32547954, 28.76557238, 16.77882424,
#        17.67202681, 25.32771032, 35.55297977, 35.70334024, 25.52159779,
#        17.1063395 , 29.49664693, 30.35848834, 18.12861705, 25.68205129,
#        15.52578456, 32.75040139, 31.86167589, 25.48676364, 20.13793157,
#        38.07889823, 22.89340938, 26.93355148, 17.30006997, 25.85419269,
#        23.04971899, 42.74893046, 23.93302231, 17.68941076, 31.1807346 ,
#        20.3978968 , 22.80932411, 28.46831435, 13.44333867, 24.92865299,
#        24.23309146, 22.85135061, 15.19212325, 20.37775453, 22.8442314 ,
#         9.47680935, 19.74923084, 12.35578254, 20.21317758, 18.87991617,
#        13.56838728, 27.14004135])

# %%
print("R^2 :       ", round(r2_score(y_test,lin_test_pred),2))
print("MAE :       ", round(mean_absolute_error(y_test,lin_test_pred),2))
print("RMSE :      ", round(np.sqrt(mean_squared_error(y_test,lin_test_pred)),2))
# Out:
# R^2 :        0.78
# MAE :        3.02
# RMSE :       4.31

# %%
print(f"Average Price: {round(df['PRICE'].mean(),2)}")
print(f"St Deviation {round(df['PRICE'].std(),2)}")
# Out:
# Average Price: 22.53
# St Deviation 9.2

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_conv = PolynomialFeatures(degree=2, include_bias=False)

# %%
poly_features = poly_conv.fit_transform(X) ## here, we are creating new variables

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.2, random_state=9)
