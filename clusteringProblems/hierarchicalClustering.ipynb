# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Car_details.csv")
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         6750.0     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         5550.0     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         2370.0     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         3375.0     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         1950.0     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %% [markdown]
# ---
# ## Edit Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   float64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 825.6+ KB

# %%
print(df.isna().sum().sum())
df.isna().sum()
# Out:
# 1100
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum().sum()
# Out:
# 0

# %%
df[["engine","cc"]] = df["engine"].str.split(" ",n=1, expand=True)

# %%
df.drop("cc", axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         6750.0     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         5550.0     120000  Diesel
#
#   seller_type transmission         owner     mileage engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl   1248      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl   1498  103.52 bhp
#
#                 torque  seats
# 0       190Nm@ 2000rpm    5.0
# 1  250Nm@ 1500-2500rpm    5.0

# %%
df[["max_power","hp"]] = df["max_power"].str.split(" ",n=1, expand=True)
df.drop("hp", axis=1, inplace=True)
df.iloc[54:56]
# Out:
#                                      name  year  selling_price  km_driven  \
# 56  Toyota Innova 2.5 G (Diesel) 7 Seater  2016        14250.0      99000
# 57             Audi A6 2.0 TDI Technology  2013        26250.0      33900
#
#       fuel seller_type transmission         owner     mileage engine  \
# 56  Diesel      Dealer       Manual   First Owner  12.99 kmpl   2494
# 57  Diesel      Dealer    Automatic  Second Owner  17.68 kmpl   1968
#
#    max_power               torque  seats
# 56     100.6  200Nm@ 1200-3600rpm    7.0
# 57    174.33  380Nm@ 1750-2500rpm    5.0

# %%
df[["mileage","km"]] = df["mileage"].str.split(" ",n=1, expand=True)
df.drop("km", axis=1, inplace=True)
df.iloc[5254:5256]
# Out:
#                    name  year  selling_price  km_driven    fuel seller_type  \
# 5403   Hyundai Verna SX  2012         5325.0      60000  Petrol      Dealer
# 5404  Hyundai i10 Magna  2010         3375.0      50000  Petrol      Dealer
#
#      transmission        owner mileage engine max_power             torque  \
# 5403       Manual  First Owner    17.7   1497    113.42  144.15nm@ 4500rpm
# 5404       Manual  First Owner   20.36   1197      78.9   111.7Nm@ 4000rpm
#
#       seats
# 5403    5.0
# 5404    5.0

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         6750.0     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         5550.0     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         2370.0     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         3375.0     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         1950.0     120000  Petrol
#
#   seller_type transmission         owner mileage engine max_power  \
# 0  Individual       Manual   First Owner    23.4   1248        74
# 1  Individual       Manual  Second Owner   21.14   1498    103.52
# 2  Individual       Manual   Third Owner    17.7   1497        78
# 3  Individual       Manual   First Owner    23.0   1396        90
# 4  Individual       Manual   First Owner    16.1   1298      88.2
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
df.drop("torque", axis=1, inplace=True)

# %%
df.iloc[756:759]
# Out:
#                                  name  year  selling_price  km_driven    fuel  \
# 783     Mahindra Bolero SLX 2WD BSIII  2009         4350.0     120000  Diesel
# 784  Mahindra Scorpio 2.6 SPORTZ CRDe  2006         3300.0     120000  Diesel
# 785            Hyundai Santro Xing GL  2009         1800.0      90000  Petrol
#
#     seller_type transmission         owner mileage engine max_power  seats
# 783  Individual       Manual   First Owner    13.6   2523        63    7.0
# 784  Individual       Manual  Second Owner    10.5   2179       120    8.0
# 785  Individual       Manual  Second Owner     0.0   1086        62    5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7906 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   float64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   object
#  9   engine         7906 non-null   object
#  10  max_power      7906 non-null   object
#  11  seats          7906 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 803.0+ KB

# %%
df = df.astype({
    'mileage': 'float64',
    'engine': 'float64',
    'max_power': 'float64'
})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7906 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   float64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   float64
#  9   engine         7906 non-null   float64
#  10  max_power      7906 non-null   float64
#  11  seats          7906 non-null   float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 803.0+ KB

# %%
df.duplicated().sum()
# Out:
# 1189

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  6717.000000    6717.000000  6.717000e+03  6717.000000  6717.000000
# mean   2013.611136    7895.789955  7.339834e+04    19.466585  1430.985857
# std       3.897402    7853.256724  5.870328e+04     4.048102   493.469198
# min    1994.000000     449.985000  1.000000e+00     0.000000   624.000000
# 25%    2011.000000    3750.000000  3.800000e+04    16.800000  1197.000000
# 50%    2014.000000    6300.000000  6.820300e+04    19.440000  1248.000000
# 75%    2017.000000    9750.000000  1.000000e+05    22.500000  1498.000000
# max    2020.000000  150000.000000  2.360457e+06    42.000000  3604.000000
#
#          max_power        seats
# count  6717.000000  6717.000000
# mean     87.766100     5.434271
# std      31.724555     0.983805
# min      32.800000     2.000000
# 25%      67.100000     5.000000
# 50%      81.830000     5.000000
# 75%     100.000000     5.000000
# max     400.000000    14.000000

# %%
df["seats"].value_counts()
# Out:
# seats
# 5.0     5254
# 7.0      966
# 8.0      221
# 4.0      124
# 9.0       74
# 6.0       57
# 10.0      18
# 2.0        2
# 14.0       1
# Name: count, dtype: int64

# %%
pd.concat({"Unique Values" : df.apply(pd.unique), "Count": df.nunique()}, axis=1)
# Out:
#                                                    Unique Values  Count
# name           [Maruti Swift Dzire VDI, Skoda Rapid 1.5 TDI A...   1982
# year           [2014, 2006, 2010, 2007, 2017, 2001, 2011, 201...     27
# selling_price  [6750.0, 5550.0, 2370.0, 3375.0, 1950.0, 6600....    670
# km_driven      [145500, 120000, 140000, 127000, 45000, 175000...    898
# fuel                                  [Diesel, Petrol, LPG, CNG]      4
# seller_type               [Individual, Dealer, Trustmark Dealer]      3
# transmission                                 [Manual, Automatic]      2
# owner          [First Owner, Second Owner, Third Owner, Fourt...      5
# mileage        [23.4, 21.14, 17.7, 23.0, 16.1, 20.14, 17.3, 2...    381
# engine         [1248.0, 1498.0, 1497.0, 1396.0, 1298.0, 1197....    121
# max_power      [74.0, 103.52, 78.0, 90.0, 88.2, 81.86, 57.5, ...    318
# seats            [5.0, 4.0, 7.0, 8.0, 6.0, 9.0, 10.0, 14.0, 2.0]      9

# %%
sns.scatterplot(x="selling_price", y="km_driven",data=df, hue="owner", palette="bright")
plt.xscale("log")
plt.yscale("log")

# %%
sns.countplot(x="seller_type", data=df)
# Out:
# <Axes: xlabel='seller_type', ylabel='count'>

# %%
sns.boxplot(x="fuel", y="selling_price", data=df)
plt.yscale("log")

# %%
sns.jointplot(x="engine", y="max_power", kind="hex", data=df, color="#063970")
plt.xlim(600,2600)
plt.ylim(25,250)
# Out:
# (25.0, 250.0)

# %%
df[df["owner"]!="Test Drive Car"]["owner"]
# Out:
# 0                First Owner
# 1               Second Owner
# 2                Third Owner
# 3                First Owner
# 4                First Owner
#                 ...
# 8121            Second Owner
# 8122            Second Owner
# 8123             First Owner
# 8124    Fourth & Above Owner
# 8125             First Owner
# Name: owner, Length: 6712, dtype: object

# %%
ax = sns.barplot(x=df[df["owner"]!="Test Drive Car"]["owner"], y="selling_price", data=df)
plt.xticks(rotation=90)
for p in ax.patches:
   ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+500))
plt.ylim(2500,10500);

# %%
df.corr(numeric_only=True)
# Out:
#                    year  selling_price  km_driven   mileage    engine  \
# year           1.000000       0.427335  -0.387918  0.366048 -0.019763
# selling_price  0.427335       1.000000  -0.161265 -0.108655  0.442772
# km_driven     -0.387918      -0.161265   1.000000 -0.196419  0.253460
# mileage        0.366048      -0.108655  -0.196419  1.000000 -0.579153
# engine        -0.019763       0.442772   0.253460 -0.579153  1.000000
# max_power      0.159889       0.692323   0.041770 -0.378609  0.683506
# seats          0.025021       0.158531   0.207890 -0.459188  0.658711
#
#                max_power     seats
# year            0.159889  0.025021
# selling_price   0.692323  0.158531
# km_driven       0.041770  0.207890
# mileage        -0.378609 -0.459188
# engine          0.683506  0.658711
# max_power       1.000000  0.259028
# seats           0.259028  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="CMRmap")
# Out:
# <Axes: >

# %% [markdown]
# ---
# ## Scaling Data

# %%
df.shape
# Out:
# (6717, 12)

# %%
dummy_df = pd.get_dummies(df.drop("name",axis=1))

# %%
dummy_df.head()
# Out:
#    year  selling_price  km_driven  mileage  engine  max_power  seats  \
# 0  2014         6750.0     145500    23.40  1248.0      74.00    5.0
# 1  2014         5550.0     120000    21.14  1498.0     103.52    5.0
# 2  2006         2370.0     140000    17.70  1497.0      78.00    5.0
# 3  2010         3375.0     127000    23.00  1396.0      90.00    5.0
# 4  2007         1950.0     120000    16.10  1298.0      88.20    5.0
#
#    fuel_CNG  fuel_Diesel  fuel_LPG  ...  seller_type_Dealer  \
# 0     False         True     False  ...               False
# 1     False         True     False  ...               False
# 2     False        False     False  ...               False
# 3     False         True     False  ...               False
# 4     False        False     False  ...               False
#
#    seller_type_Individual  seller_type_Trustmark Dealer  \
# 0                    True                         False
# 1                    True                         False
# 2                    True                         False
# 3                    True                         False
# 4                    True                         False
#
#    transmission_Automatic  transmission_Manual  owner_First Owner  \
# 0                   False                 True               True
# 1                   False                 True              False
# 2                   False                 True              False
# 3                   False                 True               True
# 4                   False                 True               True
#
#    owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                       False               False                 False
# 1                       False                True                 False
# 2                       False               False                 False
# 3                       False               False                 False
# 4                       False               False                 False
#
#    owner_Third Owner
# 0              False
# 1              False
# 2               True
# 3              False
# 4              False
#
# [5 rows x 21 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaled = scaler.fit_transform(dumdum_df)

# %%
scaled
# Out:
# array([[0.76923077, 0.04212648, 0.06164021, ..., 0.        , 0.        ,
#         0.        ],
#        [0.76923077, 0.0341024 , 0.05083721, ..., 1.        , 0.        ,
#         0.        ],
#        [0.46153846, 0.01283861, 0.05931015, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.73076923, 0.02908736, 0.04660074, ..., 0.        , 0.        ,
#         0.        ],
#        [0.5       , 0.01053169, 0.05041356, ..., 0.        , 0.        ,
#         0.        ],
#        [0.57692308, 0.03530601, 0.05083721, ..., 0.        , 0.        ,
#         0.        ]])

# %%
df_scale = pd.DataFrame(scaled, columns=dummy_df.columns)

# %%
plt.figure(figsize=(12,12), dpi=200)
sns.heatmap(df_scale, cmap="viridis")
# Out:
# <Axes: >

# %%
sns.clustermap(df_scale)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
sns.clustermap(df_scale, row_cluster=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# ---
# ## SK-Learn Cluster

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering(n_clusters=3)
cluster = model.fit_predict(df_scale)

# %%
print(len(cluster))
cluster
# Out:
# 6717
# array([0, 1, 1, ..., 2, 1, 0])

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df, x="engine", y="max_power", hue=cluster)
# Out:
# <Axes: xlabel='engine', ylabel='max_power'>

# %% [markdown]
# ### Maks Uzaklık

# %%
len(df_scale.columns)
# Out:
# 21

# %%
np.sqrt(21)
# Out:
# 4.58257569495584

# %% [markdown]
# ### distance_threshold = 0

# %%
model = AgglomerativeClustering(n_clusters=None, distance_threshold=0)

# %%
cluster_0 = model.fit_predict(df_scale)
cluster_0
# Out:
# array([3517, 6315, 6663, ...,    5,    2,    0])

# %%
len(np.unique(cluster_0))
# Out:
# 6717

# %% [markdown]
# ### Uzaklık Sınırı

# %%
clusterNum = []

for h in range(1,10):
    model = AgglomerativeClustering(n_clusters=None, distance_threshold=h)
    cluster_h = model.fit_predict(df_scale)

    a = len(np.unique(cluster_h))
    clusterNum.append(a)

# %%
plt.plot(range(1,10), clusterNum)

# %% [markdown]
# ## Dendogram

# %%
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy

# %%
linkage = hierarchy.linkage(model.children_)

# %%
linkage
# Out:
# array([[1.33000000e+03, 2.92400000e+03, 1.41421356e+00, 2.00000000e+00],
#        [8.15000000e+02, 4.69100000e+03, 2.23606798e+00, 2.00000000e+00],
#        [5.65100000e+03, 5.78400000e+03, 2.23606798e+00, 2.00000000e+00],
#        ...,
#        [6.15400000e+03, 1.34270000e+04, 4.73511352e+02, 6.71400000e+03],
#        [6.55400000e+03, 1.34280000e+04, 4.76026260e+02, 6.71500000e+03],
#        [6.39400000e+03, 1.34290000e+04, 7.26006198e+02, 6.71600000e+03]])

# %%
plt.figure(figsize=(12,6))
dendogram = hierarchy.dendrogram(linkage)

# %%
plt.figure(figsize=(10,5))
dendogram = hierarchy.dendrogram(linkage, truncate_mode="lastp", p=12)

# %%
plt.figure(figsize=(10,5))
dendogram = hierarchy.dendrogram(linkage, truncate_mode="level", p=5)

# %% [markdown]
# ---
# ## threshold_distance Choice

# %%
print(df_scale["engine"].idxmax())
print(df_scale["engine"].idxmin())
# Out:
# 129
# 348

# %%
df_scale.describe()
# Out:
#               year  selling_price    km_driven      mileage       engine  \
# count  6717.000000    6717.000000  6717.000000  6717.000000  6717.000000
# mean      0.754274       0.049788     0.031095     0.463490     0.270801
# std       0.149900       0.052513     0.024869     0.096383     0.165594
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.653846       0.022066     0.016098     0.400000     0.192282
# 50%       0.769231       0.039117     0.028894     0.462857     0.209396
# 75%       0.884615       0.062187     0.042364     0.535714     0.293289
# max       1.000000       1.000000     1.000000     1.000000     1.000000
#
#          max_power        seats     fuel_CNG  fuel_Diesel     fuel_LPG  ...  \
# count  6717.000000  6717.000000  6717.000000  6717.000000  6717.000000  ...
# mean      0.149690     0.286189     0.007593     0.544588     0.005211  ...
# std       0.086396     0.081984     0.086811     0.498045     0.072002  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.093410     0.250000     0.000000     0.000000     0.000000  ...
# 50%       0.133524     0.250000     0.000000     1.000000     0.000000  ...
# 75%       0.183007     0.250000     0.000000     1.000000     0.000000  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#        seller_type_Dealer  seller_type_Individual  \
# count         6717.000000             6717.000000
# mean             0.099151                0.896829
# std              0.298887                0.304205
# min              0.000000                0.000000
# 25%              0.000000                1.000000
# 50%              0.000000                1.000000
# 75%              0.000000                1.000000
# max              1.000000                1.000000
#
#        seller_type_Trustmark Dealer  transmission_Automatic  \
# count                   6717.000000             6717.000000
# mean                       0.004020                0.085604
# std                        0.063278                0.279799
# min                        0.000000                0.000000
# 25%                        0.000000                0.000000
# 50%                        0.000000                0.000000
# 75%                        0.000000                0.000000
# max                        1.000000                1.000000
#
#        transmission_Manual  owner_First Owner  owner_Fourth & Above Owner  \
# count          6717.000000        6717.000000                 6717.000000
# mean              0.914396           0.621706                    0.023076
# std               0.279799           0.484998                    0.150155
# min               0.000000           0.000000                    0.000000
# 25%               1.000000           0.000000                    0.000000
# 50%               1.000000           1.000000                    0.000000
# 75%               1.000000           1.000000                    0.000000
# max               1.000000           1.000000                    1.000000
#
#        owner_Second Owner  owner_Test Drive Car  owner_Third Owner
# count         6717.000000           6717.000000        6717.000000
# mean             0.281078              0.000744           0.073396
# std              0.449559              0.027275           0.260805
# min              0.000000              0.000000           0.000000
# 25%              0.000000              0.000000           0.000000
# 50%              0.000000              0.000000           0.000000
# 75%              1.000000              0.000000           0.000000
# max              1.000000              1.000000           1.000000
#
# [8 rows x 21 columns]

# %%
max = df_scale.iloc[129]
min = df_scale.iloc[348]
distance = np.linalg.norm(max-min)
distance
# RealMaks Diff
# Out:
# 2.405670403072852

# %%
model = AgglomerativeClustering(n_clusters=None, distance_threshold=2.4)

# %%
clusters = model.fit_predict(df_scale)

# %%
clusters
# Out:
# array([17,  9,  5, ..., 11, 24, 32])

# %%
len(np.unique(clusters))
# Out:
# 57
